# %%
# %pip install kaggle 
import kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#check what is the format of the file in ZIP or already CSV
file_path = '/Users/ikawahyuni/Downloads/Project Portofolio/project 7 NETFLIX/netflix_titles.csv'
with open(file_path, 'rb') as f:
    head = f.read(200)
print(head[:200])


# the file is in csv format 
# #ID,Date,... → actual CSV
# Out:
# b'show_id,type,title,director,cast,country,date_added,release_year,rating,duration,listed_in,description\ns1,Movie,Dick Johnson Is Dead,Kirsten Johnson,,United States,"September 25, 2021",2020,PG-13,90 m'

# %%
import pandas as pd 
file_path = '/Users/ikawahyuni/Downloads/Project Portofolio/project 7 NETFLIX/netflix_titles.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#the data is clean, we can load the data into sql server 
#if we use pip install pyodbc and that's not gonna work, 
# we use environment in Python 3 so we can use the code below
# !python3 -m pip install pyodbc

# %%
# !python3 -m pip install --upgrade pip

# %%
pip install sqlalchemy psycopg2-binary pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Gunakan kredensial yang SAMA dengan di DBeaver
server = 'localhost'
port = '5433'  # port yang sama dengan DBeaver
database = 'postgres'
username = 'postgres'
password = 'ikawahyuni1234'

# Connection string PostgreSQL
connection_string = f"postgresql://{username}:{password}@{server}:{port}/{database}"

engine = create_engine(connection_string)

# Tes koneksi
try:
    with engine.connect() as conn:
        result = conn.execute(text("SELECT version()")).fetchone()
        print("✅ Koneksi berhasil!")
        print(result[0])
except Exception as e:
    print("❌ Koneksi gagal:")
    print(e)
# Out:
# ✅ Koneksi berhasil!
# PostgreSQL 18.1 (Postgres.app) on aarch64-apple-darwin23.6.0, compiled by Apple clang version 15.0.0 (clang-1500.3.9.4), 64-bit

# %%
try:
    df.to_sql(
        name='netflix',           # nama tabel di PostgreSQL
        con=engine,              # koneksi engine
        if_exists='replace',     # 'replace', 'append', atau 'fail'
        index=False              # tidak menyimpan index sebagai kolom
    )
    print("✅ Data berhasil ditransfer ke PostgreSQL!")
    print(f"Jumlah baris: {len(df)}")
except Exception as e:
    print("❌ Transfer gagal:")
    print(e)
# Out:
# ✅ Data berhasil ditransfer ke PostgreSQL!
# Jumlah baris: 8807

# %%
df[df.show_id=='s5972']
# Out:
#      show_id   type     title                                director cast  \
# 5971   s5972  Movie  (T)ERROR  Lyric R. Cabral, David Felix Sutcliffe  NaN
#
#             country     date_added  release_year rating duration  \
# 5971  United States  June 30, 2016          2015     NR   84 min
#
#           listed_in                                        description
# 5971  Documentaries  This real-life look at FBI counterterrorism op...

# %%
#dibutuhkan jika di sql format column varchar (----) 
max(df.type.str.len())
--max(df.title.str.len())
--max(df.director.str.len())
--max(df.country.str.len())
--max(df.date_added.str.len())
--max(df.rating.str.len())
# Out:
# 7

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
